# %%
import pandas as pd

# %%
# Read in the Photos csv file
photos = pd.read_csv('output/labels.csv')
photos
# Out:
#     index                                           filename  \
# 0       0                        bw_img_test_depth_2_012.jpg
# 1       1                                 lyons-flooding.jpg
# 2       2                   rot-3.7_img_test_depth_2_004.jpg
# 3       3                        bw_img_test_depth_2_004.jpg
# 4       4                                          .DS_Store
# 5       5                                        images.jpeg
# 6       6                                      image_209.jpg
# 7       7                                       image_12.jpg
# 8       8                                     floodsalem.jpg
# 9       9  ba461466-c15f-4d50-aca3-0834a7d67bb4-052020_Fa...
# 10     10                 crop-0.83_img_test_depth_0_005.jpg
# 11     11                gettyimages-840306002-2048x2048.jpg
# 12     12                           img_test_depth_1_004.jpg
# 13     13                                      image_197.jpg
# ...

# %%
# Drop the row with .DS_Score

# photos.drop( 0, inplace = True)
# photos.drop( 1, inplace = True)
# photos.drop( 2, inplace = True)
# photos.drop( 3, inplace = True)
photos.drop( 4, inplace = True)

# %%
# Viewing photos dataframe
photos
# Out:
#     index                                           filename  \
# 0       0                        bw_img_test_depth_2_012.jpg
# 1       1                                 lyons-flooding.jpg
# 2       2                   rot-3.7_img_test_depth_2_004.jpg
# 3       3                        bw_img_test_depth_2_004.jpg
# 5       5                                        images.jpeg
# 6       6                                      image_209.jpg
# 7       7                                       image_12.jpg
# 8       8                                     floodsalem.jpg
# 9       9  ba461466-c15f-4d50-aca3-0834a7d67bb4-052020_Fa...
# 10     10                 crop-0.83_img_test_depth_0_005.jpg
# 11     11                gettyimages-840306002-2048x2048.jpg
# 12     12                           img_test_depth_1_004.jpg
# 13     13                                      image_197.jpg
# 14     14                                      image_127.jpg
# ...

# %%
# This function makes a new dataframe for rows that have 'Pickup truck' in one of the label columns
pickup_truck = [] 
for index, row in photos.iterrows():
    
    if row['label1'] == 'Pickup truck':
        pickup_truck.append(row)
    elif row['label2'] == 'Pickup truck':
        pickup_truck.append(row)
    elif row['label3'] == 'Pickup truck':
        pickup_truck.append(row)
    elif row['label4'] == 'Pickup truck':
        pickup_truck.append(row)
    elif row['label5'] == 'Pickup truck':
        pickup_truck.append(row)
    else:
        pass
pickup_trucks = pd.DataFrame(pickup_truck)
pickup_trucks
# Out:
#     index                            filename        label1  \
# 2       2    rot-3.7_img_test_depth_2_004.jpg       Vehicle
# 10     10  crop-0.83_img_test_depth_0_005.jpg  Land vehicle
# 19     19  crop-0.83_img_test_depth_3_003.jpg  Land vehicle
# 21     21         bw_img_test_depth_0_003.jpg  Land vehicle
# 22     22      hflip_img_test_depth_0_001.jpg  Land vehicle
# 23     23      hflip_img_test_depth_1_003.jpg       Vehicle
# 35     35  crop-0.84_img_test_depth_2_002.jpg         Water
#
#                 score1        label2              score2        label3  \
# 2    0.955994725227356  Pickup truck  0.9536613821983337           Car
# 10  0.9961627125740051       Vehicle  0.9903031587600708           Car
# 19  0.9961627125740051       Vehicle  0.9903031587600708           Car
# 21  0.9961627125740051       Vehicle  0.9903031587600708           Car
# 22  0.9961627125740051       Vehicle  0.9903031587600708           Car
# ...

# %%
# This function makes a new dataframe for rows that have 'person' in one of the label columns
person = [] 
for index, row in photos.iterrows():
    
    if row['label1'] == 'person':
        person.append(row)
    elif row['label2'] == 'person':
        person.append(row)
    elif row['label3'] == 'person':
        person.append(row)
    elif row['label4'] == 'person':
        person.append(row)
    elif row['label5'] == 'person':
        person.append(row)
    else:
        pass
persons = pd.DataFrame(person)
persons
# Out:
# Empty DataFrame
# Columns: []
# Index: []
